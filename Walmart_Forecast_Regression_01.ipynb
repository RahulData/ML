# %% [markdown]
# ## This notebook prepares the data for applying the Regression algorithms
# ### and employs the following Constructs..
# ### groupby(), agg(), sort_values(), reset_index()
# ### pd.get_dummies : Convert a categorical variable into dummy/indicator variables (like OneHotEncoder)

# %%
#######Walmart sales - data pre-processing START

import pandas as pd
import numpy as np

from datetime import datetime, timedelta
from IPython.display import display

# %%
#Let's first build a single dataframe with train and prediction dates so that any feature processing can be performed consistently

df_train = pd.read_csv('Walmart/train.csv')
# df_train = pd.read_excel('Walmart/train.xlsx')
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Date            421570 non-null object
# Weekly_Sales    421570 non-null float64
# IsHoliday       421570 non-null bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
# aggregate data per store and flag rows to differentiate from prediction placeholders

df_train = df_train.rename(columns={'Weekly_Sales': 'WeeklySales'})

df_train = df_train.groupby(['Store','Date','IsHoliday'])['WeeklySales'].agg(np.mean).to_frame().reset_index()  #its mean based on mentioned columns and the mean value is updated to WeeklySales columns; removing Dept column as well.

df_train.WeeklySales = df_train.WeeklySales.map(int)  #just to remove decimals.

df_train.head()
# Out:
#    Store       Date  IsHoliday  WeeklySales
# 0      1  1/13/2012      False        20557
# 1      1  1/14/2011      False        19591
# 2      1  1/20/2012      False        19101
# 3      1  1/21/2011      False        18436
# 4      1  1/27/2012      False        18847

# %%
df_train['Train'] = True

# test dataset
df_pred = pd.read_csv('Walmart/test.csv').drop(['Dept'], axis=1).drop_duplicates()
# df_pred = pd.read_excel('Walmart/test.xlsx').drop(['Dept'], axis=1).drop_duplicates()
df_pred['Train'] = False

df = pd.concat([df_train, df_pred])
df.sort_values(by=['Date','Store'], inplace=True)
df.reset_index(drop=True, inplace=True)

print("train: %s %s" % (df_train.Date.min(), df_train.Date.max()))
print("pred: %s %s" % (df_pred.Date.min(), df_pred.Date.max()))
# Out:
# train: 1/13/2012 9/9/2011
# pred: 1/11/2013 7/5/2013

# %%
df_train.head()
# Out:
#    Store       Date  IsHoliday  WeeklySales  Train
# 0      1  1/13/2012      False        20557   True
# 1      1  1/14/2011      False        19591   True
# 2      1  1/20/2012      False        19101   True
# 3      1  1/21/2011      False        18436   True
# 4      1  1/27/2012      False        18847   True

# %%
df_pred.head()
# Out:
#    Store        Date  IsHoliday  Train
# 0      1   11/2/2012      False  False
# 1      1   11/9/2012      False  False
# 2      1  11/16/2012      False  False
# 3      1  11/23/2012       True  False
# 4      1  11/30/2012      False  False

# %%
del(df_train)
del(df_pred)

# %%
#Break dates into week, year and Year-week

df['DateString'] = df['Date']
df['Date'] = pd.to_datetime(df['Date'])

df['Week'] = df['Date'].dt.week
df['Year'] = df['Date'].dt.year
df['YearWeek'] = df.Year.map(str) + "-" + df.Week.map(lambda v: "%02d"%v)
df.head(5)
# Out:
#         Date  IsHoliday  Store  Train  WeeklySales DateString  Week  Year  \
# 0 2013-01-11      False      1  False          NaN  1/11/2013     2  2013
# 1 2013-01-11      False      2  False          NaN  1/11/2013     2  2013
# 2 2013-01-11      False      3  False          NaN  1/11/2013     2  2013
# 3 2013-01-11      False      4  False          NaN  1/11/2013     2  2013
# 4 2013-01-11      False      5  False          NaN  1/11/2013     2  2013
#
#   YearWeek
# 0  2013-02
# 1  2013-02
# 2  2013-02
# 3  2013-02
# 4  2013-02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 9 columns):
# Date           8190 non-null datetime64[ns]
# IsHoliday      8190 non-null bool
# Store          8190 non-null int64
# Train          8190 non-null bool
# WeeklySales    6435 non-null float64
# DateString     8190 non-null object
# Week           8190 non-null int64
# Year           8190 non-null int64
# YearWeek       8190 non-null object
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 464.0+ KB

# %%
#Creating a new column with the sales increase from previous year ; playing only with Store and WeeklySales
df['WeeklySalesPreviousYear'] = np.nan

# %%
for store in df.Store.unique():
    idx = df.Store==store
    a = df['WeeklySales'][idx].values
    a = np.roll(a,52) # shift by one year
    a[0:52] = np.nan
    df.loc[idx, 'WeeklySalesPreviousYear'] = a

# %%
a
# Out:
# array([   nan,    nan,    nan,    nan,    nan,    nan,    nan,    nan,
#           nan,    nan,    nan,    nan,    nan,    nan,    nan,    nan,
#           nan,    nan,    nan,    nan,    nan,    nan,    nan,    nan,
#           nan,    nan,    nan,    nan,    nan,    nan,    nan,    nan,
#           nan,    nan,    nan,    nan,    nan,    nan,    nan,    nan,
#           nan,    nan,    nan,    nan,    nan,    nan,    nan,    nan,
#           nan,    nan,    nan,    nan,    nan, 10098.,  9909.,    nan,
#        10150.,  9761.,    nan,  9314.,  9351.,    nan, 10501., 10306.,
#        10298., 11128., 10602., 10675., 10880., 11348., 11074., 11347.,
#        11667., 10621., 10786., 11080., 10967., 11891., 11427.,    nan,
#        11376., 10805.,    nan,    nan, 17215., 17389.,    nan, 12256.,
#        11403.,    nan, 14960.,    nan, 15866., 16765., 12509.,    nan,
#        21742., 24389.,    nan, 12930., 12785., 10136.,    nan, 14075.,
#           nan, 11818., 11108.,  9661.,    nan, 12630., 11973., 12192.,
#           nan, 11074., 11116., 10598., 10975., 11683., 13293.,    nan,
#           nan, 10818., 11260.,    nan, 11262., 10948., 11549., 11511.,
#           nan, 11818., 10430., 11508.,    nan, 11430., 11543., 11611.,
#           nan, 11260., 10794.,    nan, 11671., 11421., 11674.,    nan,
#        13093., 11255., 12143., 11026.,    nan, 10464., 11739., 11170.,
#           nan, 13227., 11196., 12633.,    nan, 11330., 11674., 11316.,
#           nan, 11777., 10853., 11162.,    nan, 12205., 12203., 11780.,
#           nan,    nan, 11676., 12091., 12305., 12494., 12155., 11861.,
#           nan, 12080., 12290., 12166.,    nan, 12096.])

# %%
df
# Out:
#            Date  IsHoliday  Store  Train  WeeklySales DateString  Week  Year  \
# 0    2013-01-11      False      1  False          NaN  1/11/2013     2  2013
# 1    2013-01-11      False      2  False          NaN  1/11/2013     2  2013
# 2    2013-01-11      False      3  False          NaN  1/11/2013     2  2013
# 3    2013-01-11      False      4  False          NaN  1/11/2013     2  2013
# 4    2013-01-11      False      5  False          NaN  1/11/2013     2  2013
# 5    2013-01-11      False      6  False          NaN  1/11/2013     2  2013
# 6    2013-01-11      False      7  False          NaN  1/11/2013     2  2013
# 7    2013-01-11      False      8  False          NaN  1/11/2013     2  2013
# 8    2013-01-11      False      9  False          NaN  1/11/2013     2  2013
# 9    2013-01-11      False     10  False          NaN  1/11/2013     2  2013
# 10   2013-01-11      False     11  False          NaN  1/11/2013     2  2013
# 11   2013-01-11      False     12  False          NaN  1/11/2013     2  2013
# 12   2013-01-11      False     13  False          NaN  1/11/2013     2  2013
# 13   2013-01-11      False     14  False          NaN  1/11/2013     2  2013
# 14   2013-01-11      False     15  False          NaN  1/11/2013     2  2013
# 15   2013-01-11      False     16  False          NaN  1/11/2013     2  2013
# 16   2013-01-11      False     17  False          NaN  1/11/2013     2  2013
# 17   2013-01-11      False     18  False          NaN  1/11/2013     2  2013
# 18   2013-01-11      False     19  False          NaN  1/11/2013     2  2013
# 19   2013-01-11      False     20  False          NaN  1/11/2013     2  2013
# 20   2013-01-11      False     21  False          NaN  1/11/2013     2  2013
# 21   2013-01-11      False     22  False          NaN  1/11/2013     2  2013
# 22   2013-01-11      False     23  False          NaN  1/11/2013     2  2013
# 23   2013-01-11      False     24  False          NaN  1/11/2013     2  2013
# 24   2013-01-11      False     25  False          NaN  1/11/2013     2  2013
# 25   2013-01-11      False     26  False          NaN  1/11/2013     2  2013
# 26   2013-01-11      False     27  False          NaN  1/11/2013     2  2013
# 27   2013-01-11      False     28  False          NaN  1/11/2013     2  2013
# 28   2013-01-11      False     29  False          NaN  1/11/2013     2  2013
# 29   2013-01-11      False     30  False          NaN  1/11/2013     2  2013
# ...         ...        ...    ...    ...          ...        ...   ...   ...
# 8160 2011-09-09       True     16   True       8576.0   9/9/2011    36  2011
# 8161 2011-09-09       True     17   True      16839.0   9/9/2011    36  2011
# 8162 2011-09-09       True     18   True      14867.0   9/9/2011    36  2011
# 8163 2011-09-09       True     19   True      22066.0   9/9/2011    36  2011
# 8164 2011-09-09       True     20   True      28089.0   9/9/2011    36  2011
# 8165 2011-09-09       True     21   True       9908.0   9/9/2011    36  2011
# 8166 2011-09-09       True     22   True      14771.0   9/9/2011    36  2011
# 8167 2011-09-09       True     23   True      20046.0   9/9/2011    36  2011
# 8168 2011-09-09       True     24   True      20924.0   9/9/2011    36  2011
# 8169 2011-09-09       True     25   True       9900.0   9/9/2011    36  2011
# 8170 2011-09-09       True     26   True      15503.0   9/9/2011    36  2011
# 8171 2011-09-09       True     27   True      26548.0   9/9/2011    36  2011
# 8172 2011-09-09       True     28   True      18451.0   9/9/2011    36  2011
# 8173 2011-09-09       True     29   True       7543.0   9/9/2011    36  2011
# 8174 2011-09-09       True     30   True       7727.0   9/9/2011    36  2011
# 8175 2011-09-09       True     31   True      19120.0   9/9/2011    36  2011
# 8176 2011-09-09       True     32   True      15890.0   9/9/2011    36  2011
# 8177 2011-09-09       True     33   True       5996.0   9/9/2011    36  2011
# 8178 2011-09-09       True     34   True      13105.0   9/9/2011    36  2011
# 8179 2011-09-09       True     35   True      13767.0   9/9/2011    36  2011
# 8180 2011-09-09       True     36   True       8021.0   9/9/2011    36  2011
# 8181 2011-09-09       True     37   True       9736.0   9/9/2011    36  2011
# 8182 2011-09-09       True     38   True       7649.0   9/9/2011    36  2011
# 8183 2011-09-09       True     39   True      20419.0   9/9/2011    36  2011
# 8184 2011-09-09       True     40   True      13991.0   9/9/2011    36  2011
# 8185 2011-09-09       True     41   True      17791.0   9/9/2011    36  2011
# 8186 2011-09-09       True     42   True      12674.0   9/9/2011    36  2011
# 8187 2011-09-09       True     43   True      14425.0   9/9/2011    36  2011
# 8188 2011-09-09       True     44   True       5800.0   9/9/2011    36  2011
# 8189 2011-09-09       True     45   True      11136.0   9/9/2011    36  2011
#
#      YearWeek  WeeklySalesPreviousYear
# 0     2013-02                      NaN
# 1     2013-02                      NaN
# 2     2013-02                      NaN
# 3     2013-02                      NaN
# 4     2013-02                      NaN
# 5     2013-02                      NaN
# 6     2013-02                      NaN
# 7     2013-02                      NaN
# 8     2013-02                      NaN
# 9     2013-02                      NaN
# 10    2013-02                      NaN
# 11    2013-02                      NaN
# 12    2013-02                      NaN
# 13    2013-02                      NaN
# 14    2013-02                      NaN
# 15    2013-02                      NaN
# 16    2013-02                      NaN
# 17    2013-02                      NaN
# 18    2013-02                      NaN
# 19    2013-02                      NaN
# 20    2013-02                      NaN
# 21    2013-02                      NaN
# 22    2013-02                      NaN
# 23    2013-02                      NaN
# 24    2013-02                      NaN
# 25    2013-02                      NaN
# 26    2013-02                      NaN
# 27    2013-02                      NaN
# 28    2013-02                      NaN
# 29    2013-02                      NaN
# ...       ...                      ...
# 8160  2011-36                   8431.0
# 8161  2011-36                  14429.0
# 8162  2011-36                  15657.0
# 8163  2011-36                  20680.0
# 8164  2011-36                  29022.0
# 8165  2011-36                  10983.0
# 8166  2011-36                  16122.0
# 8167  2011-36                  21743.0
# 8168  2011-36                  19926.0
# 8169  2011-36                  10457.0
# 8170  2011-36                  15308.0
# 8171  2011-36                  25885.0
# 8172  2011-36                  16866.0
# 8173  2011-36                   8815.0
# 8174  2011-36                   8746.0
# 8175  2011-36                  19634.0
# 8176  2011-36                  16857.0
# 8177  2011-36                   5233.0
# 8178  2011-36                  14088.0
# 8179  2011-36                  13407.0
# 8180  2011-36                   7295.0
# 8181  2011-36                   9308.0
# 8182  2011-36                   7517.0
# 8183  2011-36                  21890.0
# 8184  2011-36                  14979.0
# 8185  2011-36                  19255.0
# 8186  2011-36                  10385.0
# 8187  2011-36                  12776.0
# 8188  2011-36                   6344.0
# 8189  2011-36                  12096.0
#
# [8190 rows x 10 columns]

# %%
df['WeeklySalesIncreaseRatio'] = df['WeeklySales'] / df['WeeklySalesPreviousYear']

# %%
df.tail()
# Out:
#            Date  IsHoliday  Store  Train  WeeklySales DateString  Week  Year  \
# 8185 2011-09-09       True     41   True      17791.0   9/9/2011    36  2011
# 8186 2011-09-09       True     42   True      12674.0   9/9/2011    36  2011
# 8187 2011-09-09       True     43   True      14425.0   9/9/2011    36  2011
# 8188 2011-09-09       True     44   True       5800.0   9/9/2011    36  2011
# 8189 2011-09-09       True     45   True      11136.0   9/9/2011    36  2011
#
#      YearWeek  WeeklySalesPreviousYear  WeeklySalesIncreaseRatio
# 8185  2011-36                  19255.0                  0.923968
# 8186  2011-36                  10385.0                  1.220414
# 8187  2011-36                  12776.0                  1.129070
# 8188  2011-36                   6344.0                  0.914250
# 8189  2011-36                  12096.0                  0.920635

# %%
(143+39) * 45
# Out:
# 8190

# %%
#Creating dummy variables for Store, and mapping IsHoliday to integers
stores = df.Store
df = pd.get_dummies(df, columns=['Store'])
df['Store'] = stores
df['IsHolidayInt'] = df.IsHoliday.map(int)

df.sample(5)
# Out:
#            Date  IsHoliday  Train  WeeklySales DateString  Week  Year  \
# 5654 2012-06-15      False   True       9135.0  6/15/2012    24  2012
# 4001 2012-04-13      False   True      12531.0  4/13/2012    15  2012
# 2134 2010-12-03      False   True      33096.0  12/3/2010    48  2010
# 4396 2012-04-27      False   True      15872.0  4/27/2012    17  2012
# 3834 2012-03-09      False   True      27392.0   3/9/2012    10  2012
#
#      YearWeek  WeeklySalesPreviousYear  WeeklySalesIncreaseRatio  \
# 5654  2012-24                   8509.0                  1.073569
# 4001  2012-15                  12291.0                  1.019526
# 2134  2010-48                      NaN                       NaN
# 4396  2012-17                  27071.0                  0.586310
# 3834  2012-10                  40832.0                  0.670846
#
#           ...       Store_38  Store_39  Store_40  Store_41  Store_42  \
# 5654      ...              0         0         0         0         0
# 4001      ...              0         0         0         0         1
# 2134      ...              0         0         0         0         0
# 4396      ...              0         0         0         0         0
# 3834      ...              0         0         0         0         0
#
#       Store_43  Store_44  Store_45  Store  IsHolidayInt
# 5654         0         0         0     30             0
# 4001         0         0         0     42             0
# 2134         0         0         0     20             0
# 4396         0         0         0     32             0
# 3834         0         0         0     10             0
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 57 columns):
# Date                        8190 non-null datetime64[ns]
# IsHoliday                   8190 non-null bool
# Train                       8190 non-null bool
# WeeklySales                 6435 non-null float64
# DateString                  8190 non-null object
# Week                        8190 non-null int64
# Year                        8190 non-null int64
# YearWeek                    8190 non-null object
# WeeklySalesPreviousYear     4365 non-null float64
# WeeklySalesIncreaseRatio    3735 non-null float64
# Store_1                     8190 non-null uint8
# Store_2                     8190 non-null uint8
# Store_3                     8190 non-null uint8
# Store_4                     8190 non-null uint8
# Store_5                     8190 non-null uint8
# Store_6                     8190 non-null uint8
# Store_7                     8190 non-null uint8
# Store_8                     8190 non-null uint8
# Store_9                     8190 non-null uint8
# Store_10                    8190 non-null uint8
# Store_11                    8190 non-null uint8
# Store_12                    8190 non-null uint8
# Store_13                    8190 non-null uint8
# Store_14                    8190 non-null uint8
# Store_15                    8190 non-null uint8
# Store_16                    8190 non-null uint8
# Store_17                    8190 non-null uint8
# Store_18                    8190 non-null uint8
# Store_19                    8190 non-null uint8
# Store_20                    8190 non-null uint8
# Store_21                    8190 non-null uint8
# Store_22                    8190 non-null uint8
# Store_23                    8190 non-null uint8
# Store_24                    8190 non-null uint8
# Store_25                    8190 non-null uint8
# Store_26                    8190 non-null uint8
# Store_27                    8190 non-null uint8
# Store_28                    8190 non-null uint8
# Store_29                    8190 non-null uint8
# Store_30                    8190 non-null uint8
# Store_31                    8190 non-null uint8
# Store_32                    8190 non-null uint8
# Store_33                    8190 non-null uint8
# Store_34                    8190 non-null uint8
# Store_35                    8190 non-null uint8
# Store_36                    8190 non-null uint8
# Store_37                    8190 non-null uint8
# Store_38                    8190 non-null uint8
# Store_39                    8190 non-null uint8
# Store_40                    8190 non-null uint8
# Store_41                    8190 non-null uint8
# Store_42                    8190 non-null uint8
# Store_43                    8190 non-null uint8
# Store_44                    8190 non-null uint8
# Store_45                    8190 non-null uint8
# Store                       8190 non-null int64
# IsHolidayInt                8190 non-null int64
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(4), object(2), uint8(45)
# memory usage: 1015.8+ KB

# %%
df.to_csv('Walmart/preprocessed.csv')   
#This files contains both Train and test dataset with average weekly sales.
#######Walmart sales - data pre-processing END
